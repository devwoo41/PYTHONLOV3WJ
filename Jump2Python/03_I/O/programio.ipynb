# %%
# sys1.py
import sys

args = sys.argv[1:]
for i in args:
    print(i)
# Out:
# --f=/run/user/1000/jupyter/runtime/kernel-v3e80708e904ec5dff9ea7dbdade07cf89f0630255.json

# %%
# sys2.py
import sys
args = sys.argv[1:]
for i in args:
    print(i.upper(), end=' ')
# Out:
# --F=/RUN/USER/1000/JUPYTER/RUNTIME/KERNEL-V3E80708E904EC5DFF9EA7DBDADE07CF89F0630255.JSON

# %% [markdown]
# ##### 튜플의 형태

# %%
t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ('a', 'b', ('ab', 'cd'))

# %%
t1 = (1, 2, 'a', 'b')
del t1[0] # 튜플은 삭제가 안됨
# 'tuple' object doesn't support item deletion.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 t1 = (1, 2, 'a', 'b')
# ----> 2 del t1[0] # 튜플은 삭제가 안됨
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1 = (1, 2, 'a', 'b')
t1[3]
# Out:
# 'b'

# %%
t1 = (1, 2, 'a', 'b')
t2 = 3, 4
t3 = t1 + t2
t3
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t1 = 1, 2, 'a', 'b'
len(t1)
# Out:
# 4

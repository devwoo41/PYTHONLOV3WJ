# %% [markdown]
# ##### 문자열 만들기

# %%
"Hello world"
'Python is fun'
"""Life is too short, You need Python"""
'''Life is too short, You need Python'''
# Out:
# 'Life is too short, You need Python'

# %%
food = "Python's favorite food is perl"
print(food)
# Out:
# Python's favorite food is perl

# %%
say = '"Python is very easy." he says.'
print(say)
# Out:
# "Python is very easy." he says.

# %%
food = 'Python\'s favorite food is perl'
print(food)
say = "\"Python is very easy.\" he says."
print(say)
# Out:
# Python's favorite food is perl
# "Python is very easy." he says.

# %% [markdown]
# ##### 여러 줄인 문자열을 변수에 대입하고 싶을때

# %%
multiline = "Life is too short\nYou need Python"
print(multiline)
# Out:
# Life is too short
# You need Python

# %%
multiline = '''
Life is too short
You need Python
'''
print(multiline)
# Out:
# Life is too short
# You need Python

# %% [markdown]
# ##### 이스케이프 코드
#
# \n - 문자열 안에서 줄을 바꿀 때 사용
#
# \t - 문자열 사이에 탭 간격을 줄 때 사용
#
# \\\ = \를 그대로 표현할 때 사용
#
# \\' = 작은따옴표를 그대로 표현할때 사용
#
# \\" = 큰따옴표를 그대로 표현할때 사용
#
# \r - 개리지 리턴 (줄 바꿈 문자, 커서를 현재 줄의 가장 앞으로 이동)
#
# \f - 폼 피드 (줄 바꿈 문자, 커서를 현재 줄의 다음줄로 이동)
#
# \a - 벨 소리
#
# \b - 백 스페이스
#
# \000 - 널 문자

# %% [markdown]
# ##### 문자열 연산하기

# %%
head = "Python"
tail = " is fun!"
print(head + tail)
# Out:
# Python is fun!

# %%
a = "python"
print(a * 2)
# Out:
# pythonpython

# %%
# title : multistring.py

print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ==================================================
# My Program
# ==================================================

# %%
a = "Life is too short"
print(len(a))
# Out:
# 17

# %%
a = "Life is too short, You need Python"
print(a[3])
# Out:
# e

# %%
a[-2]
# Out:
# 'o'

# %%
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'Life'

# %%
a[0:5]
# Out:
# 'Life '

# %%
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
a = "20260721Rainy"
date = a[:8]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20260721
# Rainy

# %%
"I eat %d apples." % 3
# Out:
# 'I eat 3 apples.'

# %%
"I eat %s apples." % "five"
# Out:
# 'I eat five apples.'

# %%
number = 3
"I eat %d apples." % number
# Out:
# 'I eat 3 apples.'

# %%
number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." % (number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
"Error is %d%%" % 98
# Out:
# 'Error is 98%'

# %%
"%10s" % "hi"
# Out:
# '        hi'

# %%
"%-10s" % "hi"
# Out:
# 'hi        '

# %%
"%-10sjane." % 'hi'
# Out:
# 'hi        jane.'

# %%
"%0.4f" % 3.42134234
# Out:
# '3.4213'

# %%
"%10.4f" % 3.42134234
# Out:
# '    3.4213'

# %%
"I eat {0} apples".format(3)
# Out:
# 'I eat 3 apples'

# %%
"I eat {0} apples".format("five")
# Out:
# 'I eat five apples'

# %%
number = 3
"I eat {0} apples".format(number)
# Out:
# 'I eat 3 apples'

# %%
number = 10
day = "three"
"I ate {0} apples. so I was sick for {1} days.".format(number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
"I ate {number} apples. so I was sick for {day} days.".format(number=10, day="three")
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
"{0:<10}".format("hi")
# Out:
# 'hi        '

# %%
"{0:>10}".format("hi")
# Out:
# '        hi'

# %%
"{0:^10}".format("hi")
# Out:
# '    hi    '

# %%
"{0:=^10}".format("hi")
# Out:
# '====hi===='

# %%
"{0:!<10}".format("hi")
# Out:
# 'hi!!!!!!!!'

# %%
y = 3.42134234
"{0:0.4f}".format(y)
# Out:
# '3.4213'

# %%
"{0:10.4f}".format(y)
# Out:
# '    3.4213'

# %%
"{{ and }}".format()
# Out:
# '{ and }'

# %% [markdown]
# ##### f 문자열 포매팅

# %%
name = '홍길동'
age = 30
f'나의 이름은 {name}입니다. 나이는 {age}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
age = 30
f'나는 내년이면 {age+1}살이 된다.'
# Out:
# '나는 내년이면 31살이 된다.'

# %%
d = {'name':'홍길동', 'age':30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %% [markdown]
# ##### 문자열 관련 함수들

# %%
a = "hobby"
a.count('b')
# Out:
# 2

# %%
a = "Python is the best choice"
a.find('b')
# Out:
# 14

# %%
a.find('q')
# Out:
# -1

# %%
a = "Life is too short"
a.index('t')
# Out:
# 8

# %%
",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
",".join(['a', 'b', 'c', 'd'])
# Out:
# 'a,b,c,d'

# %%
a="hi"
A=a.upper()
A
# Out:
# 'HI'

# %%
A.lower()
# Out:
# 'hi'

# %%
a= "   hi   "
a.lstrip()
# Out:
# 'hi   '

# %%
a.rstrip()
# Out:
# '   hi'

# %%
a.strip()
# Out:
# 'hi'

# %%
a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
a = "Life is too short"
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
b="A:B:C:D"
b.split(':')
# Out:
# ['A', 'B', 'C', 'D']

# %%
s = "Python"
s.isalpha()
# Out:
# True

# %%
s = "Python3"
s.isalpha()
# Out:
# False

# %%
s = "Hello world"
s.isalpha()
# Out:
# False

# %%
s = '12345'
s.isdigit()
# Out:
# True

# %%
s = "Life is too short"
s.startswith("Life")
# Out:
# True

# %%
s.endswith("short")
# Out:
# True

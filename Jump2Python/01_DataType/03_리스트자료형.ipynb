# %%
odd = [1, 3, 5, 7, 9]

# %%
a = [1, 2, 3]
a
# Out:
# [1, 2, 3]

# %%
a[0]
# Out:
# 1

# %%
a[1] + a[2]
# Out:
# 5

# %%
a = [1, 2, 3, ['a', 'b', 'c']]

# %%
a[-1]
# Out:
# ['a', 'b', 'c']

# %%
a[-1][0]
# Out:
# 'a'

# %%
a = [1, 2, ['a', 'b', ['Life', 'is']]]
a[2][2][0]
# Out:
# 'Life'

# %%
a = [1, 2, 3, 4, 5]
a[0:2]
# Out:
# [1, 2]

# %%
b = a[0:2]
c = a[2:5]
c
# Out:
# [3, 4, 5]

# %% [markdown]
# ##### 리스트 연산하기

# %%
a = [1, 2, 3]
b = [4, 5, 6]
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1, 2, 3]
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
len(a)
# Out:
# 3

# %% [markdown]
# ##### 리스트 수정과 삭제

# %%
a = [1, 2, 3]
a[2] = 4
a
# Out:
# [1, 2, 4]

# %%
a = [1, 2, 3]
del a[1]
a
# Out:
# [1, 3]

# %%
a = [1, 2, 3, 4, 5]
del a[2:]
a
# Out:
# [1, 2]

# %%
a = [1, 2, 3]
a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
a.append([5, 6])
a
# Out:
# [1, 2, 3, 4, [5, 6]]

# %%
a = [1, 4, 3, 2]
a.sort()
a
# Out:
# [1, 2, 3, 4]

# %%
a.reverse()
a
# Out:
# [4, 3, 2, 1]

# %%
a = [1, 2, 3]
a.index(3)
# Out:
# 2

# %%
a.insert(0, 4)
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3,5)
a
# Out:
# [4, 1, 2, 5, 3]

# %%
a = [1, 2, 3, 1, 2, 3]
a.remove(3)
a
# Out:
# [1, 2, 1, 2, 3]

# %%
a.remove(3)
a
# Out:
# [1, 2, 1, 2]

# %%
a = [1, 2, 3]
pop_a = a.pop()
pop_a
# Out:
# 3

# %%
a
# Out:
# [1, 2]

# %%
a = [1, 2, 3, 1]
a.count(1)
# Out:
# 2

# %%
a = [1, 2, 3]
a.extend([4, 5])
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [6, 7]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a = True
b = False
print(type(a), type(b))
# Out:
# <class 'bool'> <class 'bool'>

# %%
1 == 1
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
a = [1, 2, 3, 4]
while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
if [1,2,3]:
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
bool('Python')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
a = True and True
b = True and False
c = False and True
d = False and False
print(a, b, c, d)
# Out:
# True False False False

# %%
a = True or True
b = True or False
c = False or True
d = False or False
print(a, b, c, d)
# Out:
# True True True False

# %%
a = not True
b = not False
c = not 1
d = not 0
print(a, b, c, d)
# Out:
# False True False True

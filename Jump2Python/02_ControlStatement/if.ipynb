# %% [markdown]
# ##### if문 생성해보기

# %%
money = True
if money:
    print("택시를 타고 가라.")
else:
    print("걸어 가라.")

# 돈이 있으면 택시를 타고 가라. 없으면 걸어 가라.
# Out:
# 택시를 타고 가라.

# %% [markdown]
# ##### if문 + 비교 연산자

# %%
money = 2000
if money > 3000:
    print("택시를 타고 가라.")
else:
    print("걸어 가라.")

# 돈이 3000원 이상 있으면 택시를 타고 가라. 그렇지 않으면 걸어 가라.
# Out:
# 걸어 가라.

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket: 
    print("택시를 타고 가라.")
else:
    print("걸어 가라.")
# Out:
# 택시를 타고 가라.

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket:
    pass
else:
    print("카드를 꺼내라.")

# %% [markdown]
# ##### elif 사용하기

# %%
pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket:
    print("택시를 타고 가라")
else:
    if card:
        print("카드를 꺼내서 택시를 타고 가라.")
    else:
        print("걸어 가라.")
# Out:
# 카드를 꺼내서 택시를 타고 가라.

# %%
pocket = ['paper', 'cellphone']
card = True
if 'money' in pocket:
    print("택시를 타고 가라.")
elif card:
    print("카드를 꺼내서 택시를 타고 가라.")
else:
    print("걸어 가라.")
# Out:
# 카드를 꺼내서 택시를 타고 가라.

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket: pass
else: print("카드를 꺼내라.")

# %%
grade = 'B'
if grade == 'A':
    print("탁월한 성적입니다.")
elif grade == 'B':
    print("우수한 성적입니다.")
elif grade == 'C':
    print("보통의 성적입니다.")
else:
    print("노력이 필요합니다!")
# Out:
# 우수한 성적입니다.

# %% [markdown]
# ##### match-case

# %%
grade = 'B'
match grade:
    case 'A':
        print("탁월한 성적입니다.")
    case 'B':
        print("우수한 성적입니다.")
    case 'C':
        print("보통의 성적입니다.")
    case _:
        print("노력이 필요합니다!")
# Out:
# 우수한 성적입니다.

# %%
grade = 'B'
match grade:
    case 'A' | 'B' | 'C':
        print("합격입니다.")
    case _:
        print("불합격입니다.")
# Out:
# 합격입니다.

# %%
x = 5
(1 < x) and (x < 10)
# Out:
# True

# %%
score = 85
result = '합격' if score >= 60 else '불합격'
result
# Out:
# '합격'

# %%
age = 19
status = '성인' if age >= 18 else '미성년'
status
# Out:
# '성인'
